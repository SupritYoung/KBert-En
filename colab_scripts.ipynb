# %%
from google.colab import drive
drive.mount("/content/drive")

import os
path="/content/drive/MyDrive/workspace/K-BERT-hate-detection"
os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /content/drive
# ['colab_scripts.ipynb',
#  'outputs',
#  'requirements.txt',
#  '.gitignore',
#  'models',
#  'uer',
#  'get_kbert_repr.py',
#  'log',
#  '.idea',
#  'data',
#  'data_utils.py',
#  '__pycache__',
#  'brain',
#  'run_kbert_cls.py']

# %%
# !nvidia-smi
# Out:
# Fri Sep  9 09:11:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.3-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 7.0 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 66.0 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 43.7 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.21.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pkuseg
#   Downloading pkuseg-0.0.25-cp37-cp37m-manylinux1_x86_64.whl (50.2 MB)
#      |████████████████████████████████| 50.2 MB 196 kB/s
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pkuseg) (1.21.6)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pkuseg) (0.29.32)
# Installing collected packages: pkuseg
# Successfully installed pkuseg-0.0.25

# %%
# !python run_kbert_cls.py
# Out:
# Vocabulary file line 344 has bad format token
# Vocabulary Size:  21128
# [BertClassifier] use visible_matrix: True
# [KnowledgeGraph] Loading spo from brain/kgs/triples.spo
# Start training.
# Loading sentences from data/implicit_hate_v1_stg1_posts/train.tsv
# There are 4296 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/4296
# Shuffling dataset
# Trans data to tensor.
# input_ids
# label_ids
# mask_ids
# pos_ids
# vms
# Batch size:  32
# The number of training instances: 4296
# Epoch id: 1, Training steps: 100, Avg loss: 0.846
# Start evaluation on dev dataset.
# Loading sentences from data/implicit_hate_v1_stg1_posts/dev.tsv
# There are 17184 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/17184
# Progress of process 0: 10000/17184
# Label 0: 0.618, 1.000, 0.764
# Label 1: 0.000, 0.000, 0.000
# Label 2: 0.000, 0.000, 0.000
# Acc. (Correct/Total): 0.6182 (10624/17184)
# Start evaluation on test dataset.
# Loading sentences from data/implicit_hate_v1_stg1_posts/test.tsv
# There are 17184 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/17184
# Progress of process 0: 10000/17184
# The number of evaluation instances:  17184
# Confusion matrix:
# tensor([[10624,  5696,   864],
#         [    0,     0,     0],
#         [    0,     0,     0]])
# Report precision, recall, and f1:
# Label 0: 0.618, 1.000, 0.764
# Label 1: 0.000, 0.000, 0.000
# Label 2: 0.000, 0.000, 0.000
# Acc. (Correct/Total): 0.6182 (10624/17184)
# Epoch id: 2, Training steps: 100, Avg loss: 1.104
# Start evaluation on dev dataset.
# Loading sentences from data/implicit_hate_v1_stg1_posts/dev.tsv
# There are 17184 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/17184
# Progress of process 0: 10000/17184
# Label 0: 0.618, 1.000, 0.764
# Label 1: 0.000, 0.000, 0.000
# Label 2: 0.000, 0.000, 0.000
# Acc. (Correct/Total): 0.6182 (10624/17184)
# Epoch id: 3, Training steps: 100, Avg loss: 1.101
# Start evaluation on dev dataset.
# Loading sentences from data/implicit_hate_v1_stg1_posts/dev.tsv
# There are 17184 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/17184
# Progress of process 0: 10000/17184
# Label 0: 0.618, 1.000, 0.764
# Label 1: 0.000, 0.000, 0.000
# Label 2: 0.000, 0.000, 0.000
# Acc. (Correct/Total): 0.6182 (10624/17184)
# Epoch id: 4, Training steps: 100, Avg loss: 1.095
# Start evaluation on dev dataset.
# Loading sentences from data/implicit_hate_v1_stg1_posts/dev.tsv
# There are 17184 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/17184
# Progress of process 0: 10000/17184
# Label 0: 0.618, 1.000, 0.764
# Label 1: 0.000, 0.000, 0.000
# Label 2: 0.000, 0.000, 0.000
# Acc. (Correct/Total): 0.6182 (10624/17184)
# Epoch id: 5, Training steps: 100, Avg loss: 1.085
# Start evaluation on dev dataset.
# Loading sentences from data/implicit_hate_v1_stg1_posts/dev.tsv
# There are 17184 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/17184
# Progress of process 0: 10000/17184
# Label 0: 0.618, 1.000, 0.764
# Label 1: 0.000, 0.000, 0.000
# Label 2: 0.000, 0.000, 0.000
# Acc. (Correct/Total): 0.6182 (10624/17184)
# Final evaluation on the test dataset.
# Loading sentences from data/implicit_hate_v1_stg1_posts/test.tsv
# There are 17184 sentence in total. We use 1 processes to inject knowledge into sentences.
# Progress of process 0: 0/17184
# Progress of process 0: 10000/17184
# The number of evaluation instances:  17184
# Confusion matrix:
# tensor([[10624,  5696,   864],
#         [    0,     0,     0],
#         [    0,     0,     0]])
# Report precision, recall, and f1:
# Label 0: 0.618, 1.000, 0.764
# Label 1: 0.000, 0.000, 0.000
# Label 2: 0.000, 0.000, 0.000
# Acc. (Correct/Total): 0.6182 (10624/17184)
